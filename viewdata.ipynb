# %%
from viewRSoftData import *

plt.ion()
datapath = "/Volumes/silo4/snert/FMF_PL_rsoft/best_gridsize/"
r = Rsoftdata(datapath)

# %%
 r.readall(filename="mon_test2")
 r.plotall()
